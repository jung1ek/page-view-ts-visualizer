# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
df = pd.read_csv('fcc-forum-pageviews.csv')

# %%
df = df[(df['value'] >= df['value'].quantile(0.025)) & (df['value'] <= df['value'].quantile(0.975))]

# %%
df
# Out:
#             date   value
# 10    2016-05-19   19736
# 17    2016-05-26   18060
# 18    2016-05-27   19997
# 19    2016-05-28   19044
# 20    2016-05-29   20325
# ...          ...     ...
# 1294  2019-11-24  138875
# 1299  2019-11-29  171584
# 1300  2019-11-30  141161
# 1301  2019-12-01  142918
# 1303  2019-12-03  158549
#
# [1238 rows x 2 columns]

# %%
# sorted_df = view_df.sort_values(by='value',ascending=True)

# %%
# sorted_df
# Out:
#             date    value
# 0     2016-05-09     1201
# 2     2016-05-11     1716
# 1     2016-05-10     2329
# 7     2016-05-16     2591
# 6     2016-05-15     2927
# ...          ...      ...
# 1285  2019-11-15   314101
# 1184  2019-08-06   337325
# 1185  2019-08-07   341595
# 1135  2019-06-18  1166225
# 1134  2019-06-17  1173655
#
# [1304 rows x 2 columns]

# %%
# Calculate the 2.5th and 97.5th percentile values
# return the lowest of 2.5th value and highest of 97.5th value
lower_limit = view_df['value'].quantile(0.025)
upper_limit = view_df['value'].quantile(0.975)

# %%
# Create a boolean mask to identify rows within the desired range
mask = (view_df['value'] >= lower_limit) & (view_df['value'] <= upper_limit)

# %%
filtered_df = view_df[mask]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data into DataFrame
df = pd.read_csv('fcc-forum-pageviews.csv')
df['date'] = pd.to_datetime(df['date'])

# Create the plot
plt.figure(figsize=(16, 4))  # Adjusting figure size
plt.plot(df['date'], df['value'], color='red')

# Add title and labels
plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.xlabel('Date')
plt.ylabel('Page Views')

# Display the plot
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])

# Create the plot
fig = plt.figure(figsize=(16, 4))  # Adjusting figure size
plt.plot(df['date'], df['value'], color='red')

# Add title and labels
plt.title('Daily freeCodeCamp Forum Page Views 5/2016-12/2019')
plt.xlabel('Date')
plt.ylabel('Page Views')

# Display the plot
plt.show()

# %%
ax = fig.axes[0]

# %%
ax.get_title()
# Out:
# 'Daily freeCodeCamp Forum Page Views 5/2016-12/2019'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def draw_bar_plot(df):
    # Ensure 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Extract year and month from 'Date'
    df['Year'] = df['Date'].dt.year
    df['Month'] = df['Date'].dt.month
    
    # Calculate average daily page views for each month grouped by year
    df_grouped = df.groupby(['Year', 'Month'])['PageViews'].mean().unstack()
    
    # Create the bar plot
    ax = df_grouped.plot(kind='bar', figsize=(10, 8), legend=True)
    
    # Add labels and title
    ax.set_xlabel('Years')
    ax.set_ylabel('Average Page Views')
    ax.set_title('Average Daily Page Views per Month')
    
    # Customize the legend
    ax.legend(title='Months', labels=[
        'January', 'February', 'March', 'April', 'May', 'June',
        'July', 'August', 'September', 'October', 'November', 'December'
    ])
    
    # Display the plot
    plt.show()

# Example DataFrame creation for demonstration
data = {
    'Date': pd.date_range(start='1/1/2016', periods=1500, freq='D'),
    'PageViews': np.random.randint(1000, 200000, size=1500)
}
df = pd.DataFrame(data)

# Call the function with your DataFrame
draw_bar_plot(df)

# %%
# making it to pandas dateformat
view_df['date'] = pd.to_datetime(view_df['date'])

# extract year and month from the data
# every row got respective year and month.
view_df["year"] = view_df['date'].dt.year 
view_df['month'] = view_df['date'].dt.month

# %%
# calculate average daily page views for each month group by year
grouped_df = view_df.groupby(['year','month'])['value'].mean().unstack()

# %%
# create the bar plot
ax = grouped_df.plot(kind='bar', figsize=(10,8),legend=True)

# Add labels and title
ax.set_xlabel('Years')
ax.set_ylabel('Average Page Views')
ax.set_title('Average Daily Page Views per Month')

# customize the legend
ax.legend(title='Months',labels=['January', 'February', 'March', 'April', 'May', 'June',
        'July', 'August', 'September', 'October', 'November', 'December'])
plt.show()

# %%
# Box Diagram
# ensure date column is in datetime format
filtered_df['date'] = pd.to_datetime(filtered_df['date'])

# prepare data for box plots
filtered_df['year'] = filtered_df['date'].dt.year
filtered_df['month'] = filtered_df['date'].dt.month
filtered_df['month_name'] = filtered_df['date'].dt.strftime('%b') # month names
# Out:
# C:\Users\Jung__tek\AppData\Local\Temp\ipykernel_8700\192906432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['date'] = pd.to_datetime(filtered_df['date'])
# C:\Users\Jung__tek\AppData\Local\Temp\ipykernel_8700\192906432.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['year'] = filtered_df['date'].dt.year
# C:\Users\Jung__tek\AppData\Local\Temp\ipykernel_8700\192906432.py:7: SettingWithCopyWarning:
# ...

# %%
# sort by month to ensure corret order of the plot
filtered_df = filtered_df.sort_values('month')

# Creating the figure and axes
fig, axes = plt.subplots(1,2,figsize=(20,7))

# Year wise box plot (Trend)
sns.boxplot(ax=axes[0], x='year',y='value',data=filtered_df)
axes[0].set_title('Year-Wise Box Plot (Trend)')
axes[0].set_xlabel('Year')
axes[0].set_ylabel('Page Views')

# Month-wise Box Plot (Seasonality)
sns.boxplot(ax=axes[1],x='month_name',y='value',data=filtered_df)
axes[1].set_title('Month-wise Box Plot (Seasonality)')
axes[1].set_xlabel('Month')
axes[1].set_ylabel('Page Views')
plt.show()

# %%
df_box = df.copy()
df_box.reset_index(inplace=True)
df_box['year'] = [d.year for d in df_box.date]
df_box['month'] = [d.strftime('%b') for d in df_box.date]

# %%
def draw_box_plot():
    # Prepare data for box plots (this part is done!)
    df_box = df.copy()
    df_box.reset_index(inplace=True)
    df_box['year'] = [d.year for d in df_box.date]
    df_box['month'] = [d.strftime('%b') for d in df_box.date]
    df_box['month_num'] = df_box['date'].dt.month

    # Draw box plots (using Seaborn)

    df_box = df_box.sort_values('month')

    # Creating the figure and axes
    fig, axes = plt.subplots(1,2,figsize=(20,7))

    # Year wise box plot (Trend)
    sns.boxplot(ax=axes[0], x='year',y='value',data=df_box)
    axes[0].set_title('Year-Wise Box Plot (Trend)')
    axes[0].set_xlabel('Year')
    axes[0].set_ylabel('Page Views')

    # Month-wise Box Plot (Seasonality)
    sns.boxplot(ax=axes[1],x='month',y='value',data=df_box)
    axes[1].set_title('Month-wise Box Plot (Seasonality)')
    axes[1].set_xlabel('Month')
    axes[1].set_ylabel('Page Views')



    # Save image and return fig (don't change this part)
    fig.savefig('box_plot.png')
    return fig

# %%
draw_box_plot()

# %%
def draw_bar_plot():
    # Copy and modify data for monthly bar plot
    # making it to pandas dateformat
    df_bar = df.copy()
    df_bar['date'] = pd.to_datetime(df['date'])

    # Draw bar plot
    df_bar['year'] = df_bar['date'].dt.year
    df_bar['month'] = df_bar['date'].dt.month

    df_bar = df_bar.groupby(['year','month'])['value'].mean().unstack()
    fig, ax = plt.subplots(figsize=(10, 8))

    df_bar.plot(kind='bar',ax=ax,legend=True)
    # Add labels and title
    fig.set_xlabel('Years')
    fig.set_ylabel('Average Page Views')
    fig.set_title('Average Daily Page Views per Month')

    # customize the legend
    fig.legend(title='Months',labels=['January', 'February', 'March', 'April', 'May', 'June',
        'July', 'August', 'September', 'October', 'November', 'December'])


    # Save image and return fig (don't change this part)
    fig.get_figure().savefig('bar_plot.png')
    return fig

# %%
draw_bar_plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 draw_bar_plot()
#
# Cell In[21], line 16, in draw_bar_plot()
#      14 df_bar.plot(kind='bar',ax=ax,legend=True)
#      15 # Add labels and title
# ---> 16 fig.set_xlabel('Years')
#      17 fig.set_ylabel('Average Page Views')
#      18 fig.set_title('Average Daily Page Views per Month')
#
# AttributeError: 'Figure' object has no attribute 'set_xlabel'
